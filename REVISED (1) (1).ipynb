# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("DATASET.csv")

# %%
df.dtypes
# Out:
# mileage                   int64
# price                     int64
# model_year                int64
# make                     object
# model                    object
# series                   object
# style                    object
# certified                 int64
# price_analysis            int64
# drivetrain_from_vin      object
# engine_from_vin          object
# transmission_from_vin    object
# fuel_type_from_vin       object
# number_price_changes      int64
# stock_type               object
# dtype: object

# %%
df_copy=df.copy()

# %%
# Check for missing values in different forms
# Define special_missing_values first!
special_missing_values = ['N/A', '?', '-']  # Replace with your actual special missing values

missing_summary = pd.DataFrame({
    "NaN Count": df_copy.isnull().sum(),
    "Zero Count": (df_copy == 0).sum(),
    "Empty String Count": (df_copy == "").sum(),
    "Special Missing Count": df_copy.isin(special_missing_values).sum()
})

# Display the missing value summary
print(missing_summary)
# Out:
#                        NaN Count  Zero Count  Empty String Count  \
# mileage                        0       10175                   0
# price                          0        4340                   0
# model_year                     0           0                   0
# make                           0           0                   0
# model                          0           0                   0
# series                       825           0                   0
# style                          0           0                   0
# certified                      0      144156                   0
# price_analysis                 0      133080                   0
# drivetrain_from_vin            0           0                   0
# engine_from_vin                0           0                   0
# transmission_from_vin          0           0                   0
# fuel_type_from_vin             0           0                   0
# number_price_changes           0       59921                   0
# stock_type                     0           0                   0
#
#                        Special Missing Count
# mileage                                    0
# price                                      0
# model_year                                 0
# make                                       0
# model                                      0
# series                                     0
# style                                      0
# certified                                  0
# price_analysis                             0
# drivetrain_from_vin                        0
# engine_from_vin                            0
# transmission_from_vin                      0
# fuel_type_from_vin                         0
# number_price_changes                       0
# stock_type                                 0

# %%
# Get the count of unique values for each column
unique_counts = df_copy.nunique()

# Display the counts of unique values for each column
print(unique_counts)
# Out:
# mileage                  46874
# price                    39651
# model_year                  38
# make                        45
# model                      702
# series                    1630
# style                      664
# certified                    2
# price_analysis               2
# drivetrain_from_vin          4
# engine_from_vin            974
# transmission_from_vin        4
# fuel_type_from_vin           7
# number_price_changes       120
# stock_type                   2
# dtype: int64

# %%
df_copy.drop('series', axis=1, inplace=True)

# %%
df
# Out:
#         mileage   price  model_year       make         model  \
# 0        230860   11500        1987  Chevrolet        Camaro
# 1         48905    8700        1988   Chrysler  Fifth Avenue
# 2        174640    6000        1989   Cadillac       DeVille
# 3        174640    6000        1989   Cadillac       DeVille
# 4        288000    8500        1989  Chevrolet        Camaro
# ...         ...     ...         ...        ...           ...
# 145109       30  105781        2024      Volvo          XC90
# 145110       30  105990        2024      Volvo          XC90
# 145111     2454  108201        2024      Volvo          XC90
# 145112     2454  108201        2024      Volvo          XC90
# 145113     9333       0        2024      Volvo          XC90
#
#                    series           style  certified  price_analysis  \
# 0                Iroc Z28        2D Coupe          0               0
# 1                     NaN        4D Sedan          0               0
# 2                     NaN        4D Sedan          0               0
# 3                     NaN        4D Sedan          0               0
# 4                     Z28        2D Coupe          0               0
# ...                   ...             ...        ...             ...
# 145109  Recharge Ultimate  4D Utility AWD          0               0
# 145110  Recharge Ultimate  4D Utility AWD          0               0
# 145111  Recharge Ultimate  4D Utility AWD          0               0
# 145112  Recharge Ultimate  4D Utility AWD          0               0
# 145113  Recharge Ultimate  4D Utility AWD          0               0
#
#        drivetrain_from_vin        engine_from_vin transmission_from_vin  \
# 0                      RWD           5.7L V8 TBI                      A
# 1                      RWD               5.2L V8                      A
# 2                      FWD            4.5L V8 DI                      A
# 3                      FWD            4.5L V8 DI                      A
# 4                      RWD           5.7L V8 TBI                      A
# ...                    ...                    ...                   ...
# 145109                 AWD  2.0L I-4 DI PHEV T/C                      A
# 145110                 AWD  2.0L I-4 DI PHEV T/C                      A
# 145111                 AWD  2.0L I-4 DI PHEV T/C                      A
# 145112                 AWD  2.0L I-4 DI PHEV T/C                      A
# 145113                 AWD  2.0L I-4 DI PHEV T/C                      A
#
#        fuel_type_from_vin  number_price_changes stock_type
# 0                     Gas                     0       USED
# 1                     Gas                     0       USED
# 2                     Gas                     0       USED
# 3                     Gas                     4       USED
# 4                     Gas                     0       USED
# ...                   ...                   ...        ...
# 145109               PHEV                    25        NEW
# 145110               PHEV                    22        NEW
# 145111               PHEV                     2       USED
# 145112               PHEV                    10        NEW
# 145113               PHEV                     0       USED
#
# [145114 rows x 15 columns]

# %%
# Count the number of vehicles with 0 mileage grouped by stock_type (New/Used)
zero_mileage_counts = df_copy[df_copy["mileage"] == 0]["stock_type"].value_counts()

# Display the result
zero_mileage_counts
# Out:
# stock_type
# NEW     10147
# USED       28
# Name: count, dtype: int64

# %%
# Step 1: Replace 'NEW' with 0
df_copy['mileage'] = df_copy['mileage'].replace('New', 0)

# Step 2: Replace 'USED' with the median mileage
median_mileage = df_copy[df_copy['mileage'] > 0]['mileage'].median()  # Calculate the median of used vehicles
df_copy.loc[(df_copy['stock_type'] == 'USED') & (df_copy['mileage'] == 0), 'mileage'] = median_mileage

# %%
df_copy
# Out:
#         mileage   price  model_year       make         model           style  \
# 0        230860   11500        1987  Chevrolet        Camaro        2D Coupe
# 1         48905    8700        1988   Chrysler  Fifth Avenue        4D Sedan
# 2        174640    6000        1989   Cadillac       DeVille        4D Sedan
# 3        174640    6000        1989   Cadillac       DeVille        4D Sedan
# 4        288000    8500        1989  Chevrolet        Camaro        2D Coupe
# ...         ...     ...         ...        ...           ...             ...
# 145109       30  105781        2024      Volvo          XC90  4D Utility AWD
# 145110       30  105990        2024      Volvo          XC90  4D Utility AWD
# 145111     2454  108201        2024      Volvo          XC90  4D Utility AWD
# 145112     2454  108201        2024      Volvo          XC90  4D Utility AWD
# 145113     9333       0        2024      Volvo          XC90  4D Utility AWD
#
#         certified  price_analysis drivetrain_from_vin        engine_from_vin  \
# 0               0               0                 RWD           5.7L V8 TBI
# 1               0               0                 RWD               5.2L V8
# 2               0               0                 FWD            4.5L V8 DI
# 3               0               0                 FWD            4.5L V8 DI
# 4               0               0                 RWD           5.7L V8 TBI
# ...           ...             ...                 ...                    ...
# 145109          0               0                 AWD  2.0L I-4 DI PHEV T/C
# 145110          0               0                 AWD  2.0L I-4 DI PHEV T/C
# 145111          0               0                 AWD  2.0L I-4 DI PHEV T/C
# 145112          0               0                 AWD  2.0L I-4 DI PHEV T/C
# 145113          0               0                 AWD  2.0L I-4 DI PHEV T/C
#
#        transmission_from_vin fuel_type_from_vin  number_price_changes  \
# 0                          A                Gas                     0
# 1                          A                Gas                     0
# 2                          A                Gas                     0
# 3                          A                Gas                     4
# 4                          A                Gas                     0
# ...                      ...                ...                   ...
# 145109                     A               PHEV                    25
# 145110                     A               PHEV                    22
# 145111                     A               PHEV                     2
# 145112                     A               PHEV                    10
# 145113                     A               PHEV                     0
#
#        stock_type
# 0            USED
# 1            USED
# 2            USED
# 3            USED
# 4            USED
# ...           ...
# 145109        NEW
# 145110        NEW
# 145111       USED
# 145112        NEW
# 145113       USED
#
# [145114 rows x 14 columns]

# %%
# Check the number of missing values in the mileage column
missing_values = df_copy['mileage'].isnull().sum()
print(f"Missing values in 'mileage' column: {missing_values}")
# Out:
# Missing values in 'mileage' column: 0

# %%
df_copy['transmission_from_vin'].value_counts()
# Out:
# transmission_from_vin
# A    141105
# M      3975
# 7        32
# 6         2
# Name: count, dtype: int64

# %%
df_copy['transmission_from_vin'] = df_copy['transmission_from_vin'].replace({'7': 'A', '6': 'M'})
print(df_copy['transmission_from_vin'].unique())
# Out:
# ['A' 'M']

# %%
from sklearn.impute import KNNImputer

# Replace zeros with NaN
df_copy['price'] = df_copy['price'].replace(0, np.nan)

# Apply KNN Imputer
imputer = KNNImputer(n_neighbors=5)
df_copy['price'] = imputer.fit_transform(df_copy[['price', 'mileage', 'model_year']])[:, 0]

# Check the number of missing values in the price column
missing_values = df_copy['price'].isnull().sum()
print(f"Missing values in 'price' column: {missing_values}")
# Out:
# Missing values in 'price' column: 0

# %%
# Get unique values for the "Certified" and "Price Analysis" columns
df_copy['price_analysis'].value_counts()
# Out:
# price_analysis
# 0    133080
# 1     12034
# Name: count, dtype: int64

# %%
df_copy['certified'].value_counts()
# Out:
# certified
# 0    144156
# 1       958
# Name: count, dtype: int64

# %%
# Ensure the column is treated as a string, then extract only numeric engine displacement
df_copy['engine_from_vin'] = df_copy['engine_from_vin'].astype(str).str.extract(r'(\d+\.\d+)')

# %%
# Replace zeros with NaN
df_copy['engine_from_vin'] = df_copy['engine_from_vin'].replace(0, np.nan)

# Apply KNN Imputer
imputer = KNNImputer(n_neighbors=5)
df_copy['engine_from_vin'] = imputer.fit_transform(df_copy[['engine_from_vin', 'mileage', 'model_year']])[:, 0]

# Check the number of missing values in the price column
missing_values = df_copy['engine_from_vin'].isnull().sum()
print(f"Missing values in 'engine_from_vin' column: {missing_values}")
# Out:
# Missing values in 'engine_from_vin' column: 0

# %%
df_copy.isnull().sum() + (df == 0).sum()
# Out:
# certified                144156.0
# drivetrain_from_vin           0.0
# engine_from_vin               0.0
# fuel_type_from_vin            0.0
# make                          0.0
# mileage                   10175.0
# model                         0.0
# model_year                    0.0
# number_price_changes      59921.0
# price                      4340.0
# price_analysis           133080.0
# series                        NaN
# stock_type                    0.0
# style                         0.0
# transmission_from_vin         0.0
# dtype: float64

# %%
df_clean_dulpicated_sum = {f"The number of duplicated rows are: {df_copy.duplicated().sum()}"}  # Replace df_clean with df_copy
print(df_clean_dulpicated_sum)
# Out:
# {'The number of duplicated rows are: 28201'}

# %%
df_copy.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 145109    False
# 145110    False
# 145111    False
# 145112    False
# 145113    False
# Length: 145114, dtype: bool

# %%
df_copy.shape
# Out:
# (145114, 14)

# %%
df_copy.drop_duplicates(inplace=True)

# %%
df_copy.shape
# Out:
# (116913, 14)

# %%
# Columns to check for outliers
import seaborn as sns
import matplotlib.pyplot as plt
columns_to_check = ['price_analysis', 'model_year', 'number_price_changes']

# Create box plots
plt.figure(figsize=(12, 6))

for i, col in enumerate(columns_to_check, 1):
    plt.subplot(1, len(columns_to_check), i)
    sns.boxplot(y=df_copy[col])
    plt.title(f"Box Plot of {col}")

plt.tight_layout()
plt.show()

# %%
# Columns to check for outliers
columns_to_check = ['price_analysis', 'model_year', 'number_price_changes']

# Function to detect outliers using IQR
def detect_outliers_iqr(data, column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Identify outliers
    outliers = data[(data[column] < lower_bound) | (data[column] > upper_bound)]

    return outliers

# Apply IQR method and print outliers for each column
for col in columns_to_check:
    outliers = detect_outliers_iqr(df_copy, col)
    print(f"Outliers in {col}:")
    print(outliers)
    print("\n")
# Out:
# Outliers in price_analysis:
#         mileage    price  model_year       make       model           style  \
# 6         21364  29900.0        1990      Dodge     Ram 150        Club Cab
# 26       533380    995.0        1995        GMC     C/K1500     Ext Cab 4WD
# 28        48654  28000.0        1996  Chevrolet     C/K3500    Crew Cab 4WD
# 36       395698   3609.0        1997       Ford    Explorer  4D Utility 4WD
# 39       231123   1988.0        1998  Chevrolet  Astro Vans       Ext Wagon
# ...         ...      ...         ...        ...         ...             ...
# 140547        0  55534.0        2024     Toyota       Venza  4D Utility AWD
# 140548        5  56100.0        2024     Toyota       Venza  4D Utility AWD
# 140553        0  45579.0        2024     Toyota       Venza  4D Utility AWD
# 140559        0  51075.0        2024     Toyota       Venza  4D Utility AWD
# 140564        0  57535.0        2024     Toyota       Venza  4D Utility AWD
#
#         certified  price_analysis drivetrain_from_vin  engine_from_vin  \
# 6               0               1                 RWD              5.2
# 26              0               1                 4WD              5.7
# 28              0               1                 4WD              6.5
# 36              0               1                 4WD              4.0
# 39              0               1                 RWD              4.3
# ...           ...             ...                 ...              ...
# 140547          0               1                 AWD              2.5
# 140548          0               1                 AWD              2.5
# 140553          0               1                 AWD              2.5
# 140559          0               1                 AWD              2.5
# 140564          0               1                 AWD              2.5
#
#        transmission_from_vin fuel_type_from_vin  number_price_changes  \
# 6                          A                Gas                     1
# 26                         A                CNG                     1
# 28                         A             Diesel                     0
# 36                         A                Gas                     2
# 39                         A                Gas                     0
# ...                      ...                ...                   ...
# 140547                     A             Hybrid                     2
# 140548                     A             Hybrid                     1
# 140553                     A             Hybrid                     0
# 140559                     A             Hybrid                     0
# 140564                     A             Hybrid                     1
#
#        stock_type
# 6            USED
# 26           USED
# 28           USED
# 36           USED
# 39           USED
# ...           ...
# 140547        NEW
# 140548        NEW
# 140553        NEW
# 140559        NEW
# 140564        NEW
#
# [9642 rows x 14 columns]
#
#
# Outliers in model_year:
#       mileage    price  model_year        make         model  \
# 0      230860  11500.0        1987   Chevrolet        Camaro
# 1       48905   8700.0        1988    Chrysler  Fifth Avenue
# 2      174640   6000.0        1989    Cadillac       DeVille
# 3      174640   6000.0        1989    Cadillac       DeVille
# 4      288000   8500.0        1989   Chevrolet        Camaro
# ...       ...      ...         ...         ...           ...
# 5511   130467  12995.0        2013  Volkswagen        Tiguan
# 5512   133558  16700.0        2013  Volkswagen        Tiguan
# 5514    97611  18907.0        2013  Volkswagen       Touareg
# 5515   170790  14800.0        2013       Volvo          XC60
# 5516   150972  12980.0        2013       Volvo          XC60
#
#                    style  certified  price_analysis drivetrain_from_vin  \
# 0               2D Coupe          0               0                 RWD
# 1               4D Sedan          0               0                 RWD
# 2               4D Sedan          0               0                 FWD
# 3               4D Sedan          0               0                 FWD
# 4               2D Coupe          0               0                 RWD
# ...                  ...        ...             ...                 ...
# 5511  4D Utility 4Motion          0               1                 AWD
# 5512  4D Utility 4Motion          0               0                 AWD
# 5514      4D Utility 3.6          0               0                 AWD
# 5515      4D Utility AWD          0               0                 AWD
# 5516      4D Utility AWD          0               1                 AWD
#
#       engine_from_vin transmission_from_vin fuel_type_from_vin  \
# 0                 5.7                     A                Gas
# 1                 5.2                     A                Gas
# 2                 4.5                     A                Gas
# 3                 4.5                     A                Gas
# 4                 5.7                     A                Gas
# ...               ...                   ...                ...
# 5511              2.0                     A                Gas
# 5512              2.0                     A                Gas
# 5514              3.6                     A                Gas
# 5515              3.0                     A                Gas
# 5516              3.0                     A                Gas
#
#       number_price_changes stock_type
# 0                        0       USED
# 1                        0       USED
# 2                        0       USED
# 3                        4       USED
# 4                        0       USED
# ...                    ...        ...
# 5511                     1       USED
# 5512                     0       USED
# 5514                     0       USED
# 5515                     4       USED
# 5516                     0       USED
#
# [4480 rows x 14 columns]
#
#
# Outliers in number_price_changes:
#         mileage     price  model_year           make      model  \
# 5        198839   39900.0        1989     Volkswagen  Cabriolet
# 31       345000   15900.0        1996           Jeep   Cherokee
# 48       132220    9888.0        1998  Mercedes-Benz  SLK-Class
# 98       287000    5600.0        2001          Lexus      RX300
# 289      258000    6999.0        2004         Nissan     Xterra
# ...         ...       ...         ...            ...        ...
# 145105       30   99542.0        2024          Volvo       XC90
# 145107       30  102016.0        2024          Volvo       XC90
# 145108       30  103950.0        2024          Volvo       XC90
# 145109       30  105781.0        2024          Volvo       XC90
# 145110       30  105990.0        2024          Volvo       XC90
#
#                  style  certified  price_analysis drivetrain_from_vin  \
# 5          Convertible          0               0                 FWD
# 31      4D Utility 4WD          0               0                 4WD
# 48         2D Roadster          0               0                 RWD
# 98          4D Utility          0               0                 FWD
# 289     4D Utility S/C          0               0                 RWD
# ...                ...        ...             ...                 ...
# 145105  4D Utility AWD          0               0                 AWD
# 145107  4D Utility AWD          0               0                 AWD
# 145108  4D Utility AWD          0               0                 AWD
# 145109  4D Utility AWD          0               0                 AWD
# 145110  4D Utility AWD          0               0                 AWD
#
#         engine_from_vin transmission_from_vin fuel_type_from_vin  \
# 5                   1.8                     A                Gas
# 31                  4.0                     A                Gas
# 48                  2.3                     A                Gas
# 98                  3.0                     A                Gas
# 289                 3.3                     M                Gas
# ...                 ...                   ...                ...
# 145105              2.0                     A               PHEV
# 145107              2.0                     A               PHEV
# 145108              2.0                     A               PHEV
# 145109              2.0                     A               PHEV
# 145110              2.0                     A               PHEV
#
#         number_price_changes stock_type
# 5                         13       USED
# 31                        19       USED
# 48                        23       USED
# 98                        11       USED
# 289                       13       USED
# ...                      ...        ...
# 145105                    18        NEW
# 145107                    29        NEW
# 145108                    22        NEW
# 145109                    25        NEW
# 145110                    22        NEW
#
# [10791 rows x 14 columns]

# %% [markdown]
# Price Analysis Outliers:
# Some cars have extremely high or low prices, which may indicate rare models or errors.
# Older cars tend to have lower prices, while newer ones have very high prices.
# Used cars generally show more variation in pricing than new ones.
#
#
# Model Year Outliers:
# Very old cars (1980s-90s) and brand-new cars (2024) stand out in the data.
# Older cars might be rare collectibles or heavily used, affecting their value.
# Newer cars have high prices, likely due to demand and dealership pricing.
#
#
# Number of Price Changes Outliers:
# Some cars have had too many price changes, which might indicate demand fluctuations.
# Frequent price changes could be due to dealership strategies or incorrect data.
# Cars with very few or no price changes are likely stable in demand or pricing.
